# %%
import pandas as pd

# %%
customers_upd=pd.read_csv(r"C:\Users\Rohini\Downloads\us_customer_data.csv")

# %%
transaction_table=pd.read_csv(r"C:\Users\Rohini\Downloads\transaction_data.csv")

# %%
merged_table=pd.merge(customers_upd,transaction_table,on="customer_id",how="inner")

# %%
merged_table
# Out:
#      customer_id              name                        email  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com
# 2              5  Matthew Phillips        qwilliams@example.com
# 3              7      Louis Miller  patriciaelliott@example.org
# 4              7      Louis Miller  patriciaelliott@example.org
# ..           ...               ...                          ...
# 995          995    Deanna Johnson            ycook@example.org
# 996          995    Deanna Johnson            ycook@example.org
# 997          997      Jodi Simpson           eric24@example.org
# 998          998     Crystal Brown         pshaffer@example.net
# 999          998     Crystal Brown         pshaffer@example.net
#
#                       phone  \
# 0                       NaN
# 1    001-947-633-4224x07930
# 2     001-869-650-5682x8385
# 3      001-418-931-4146x588
# 4      001-418-931-4146x588
# ...

# %%
merged_table.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                30
# phone                54
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount               50
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
merged_table['amount']=merged_table['amount'].fillna(merged_table['amount'].mean())

# %%
merged_table.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                30
# phone                54
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount                0
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
merged_table['email']=merged_table['email'].fillna(merged_table['name'].str.replace(' ','').str.lower()+'@unknown.com')

# %%
merged_table.isnull().sum()
# Out:
# customer_id           0
# name                  0
# email                 0
# phone                54
# address               0
# registration_date     0
# loyalty_status        0
# transaction_id        0
# amount                0
# transaction_date      0
# product_category      0
# payment_method        0
# store_location        0
# dtype: int64

# %%
merged_table['phone']=merged_table['phone'].fillna('xxx-xxx-xxxx')
merged_table['phone']=merged_table['phone'].str.replace('-','')
merged_table.loc[merged_table['phone'].str.len()<10,'phone']='xxxxxxxxx'

# %%
merged_table['phone']=merged_table['phone'].str.replace(r'\D','',regex=True)
merged_table['phone']=merged_table['phone'].str.slice(0,11)

# %%
merged_table.isnull().sum()
# Out:
# customer_id          0
# name                 0
# email                0
# phone                0
# address              0
# registration_date    0
# loyalty_status       0
# transaction_id       0
# amount               0
# transaction_date     0
# product_category     0
# payment_method       0
# store_location       0
# dtype: int64

# %%
merged_table
# Out:
#      customer_id              name                        email        phone  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com  00194763342
# 2              5  Matthew Phillips        qwilliams@example.com  00186965056
# 3              7      Louis Miller  patriciaelliott@example.org  00141893141
# 4              7      Louis Miller  patriciaelliott@example.org  00141893141
# ..           ...               ...                          ...          ...
# 995          995    Deanna Johnson            ycook@example.org  16398532802
# 996          995    Deanna Johnson            ycook@example.org  16398532802
# 997          997      Jodi Simpson           eric24@example.org  14086815204
# 998          998     Crystal Brown         pshaffer@example.net   9625217928
# 999          998     Crystal Brown         pshaffer@example.net   9625217928
#
# ...

# %%
high_value_transactions=merged_table[merged_table['amount']>1000]

# %%
high_value_transactions
# Out:
#      customer_id              name                        email        phone  \
# 0              1     Michelle Kidd           vayala@example.net
# 1              4    Kimberly Price    jessicaknight@example.com  00194763342
# 2              5  Matthew Phillips        qwilliams@example.com  00186965056
# 3              7      Louis Miller  patriciaelliott@example.org  00141893141
# 6             10      Rachel White     whitemichael@example.org  00192079345
# ..           ...               ...                          ...          ...
# 991          991     Erica Fleming          erica85@example.net
# 992          992    Thomas Stevens    vargasmatthew@example.org   7698643179
# 993          995    Deanna Johnson            ycook@example.org  16398532802
# 994          995    Deanna Johnson            ycook@example.org  16398532802
# 999          998     Crystal Brown         pshaffer@example.net   9625217928
#
# ...

# %%
high_value_transactions.to_csv("q3.csv",index=False)
